# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('D:\Descargas\owid-covid-data  - copia.csv')
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=260567, step=1)

# %%
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                 float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.describe(include='all')
# Out:
#        iso_code continent   location        date   total_cases     new_cases  \
# count    260567    245944     260567      260567  2.460270e+05  2.457040e+05
# unique      248         6        248        1154           NaN           NaN
# top         ARG    Europe  Argentina  2021-09-23           NaN           NaN
# freq       1154     59595       1154         247           NaN           NaN
# mean        NaN       NaN        NaN         NaN  5.351606e+06  1.171424e+04
# std         NaN       NaN        NaN         NaN  3.286233e+07  8.174768e+04
# min         NaN       NaN        NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN        NaN         NaN  5.833500e+03  0.000000e+00
# 50%         NaN       NaN        NaN         NaN  6.252100e+04  3.600000e+01
# 75%         NaN       NaN        NaN         NaN  6.499290e+05  8.110000e+02
# max         NaN       NaN        NaN         NaN  6.750579e+08  4.082893e+06
#
# ...

# %%
#df.info()
#df.describe()

# %%
df.shape
# Out:
# (260567, 67)

# %%
df.isnull().head()
# Out:
#    iso_code  continent  location   date  total_cases  new_cases  \
# 0     False      False     False  False        False      False
# 1     False      False     False  False        False      False
# 2     False      False     False  False        False      False
# 3     False      False     False  False        False      False
# 4     False      False     False  False        False      False
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                True          True        True                 True  ...
# 1                True          True        True                 True  ...
# 2                True          True        True                 True  ...
# 3                True          True        True                 True  ...
# 4                True          True        True                 True  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   14623
# location                                        0
# date                                            0
# total_cases                                 14540
#                                             ...
# population                                   1117
# excess_mortality_cumulative_absolute       251918
# excess_mortality_cumulative                251918
# excess_mortality                           251918
# excess_mortality_cumulative_per_million    251918
# Length: 67, dtype: int64

# %%
#df['date']
df[['date']]
# Out:
#               date
# 0       2020-02-24
# 1       2020-02-25
# 2       2020-02-26
# 3       2020-02-27
# 4       2020-02-28
# ...            ...
# 260562  2023-02-23
# 260563  2023-02-24
# 260564  2023-02-25
# 260565  2023-02-26
# 260566  2023-02-27
#
# [260567 rows x 1 columns]

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 260562    False
# 260563    False
# 260564    False
# 260565    False
# 260566    False
# Length: 260567, dtype: bool

# %%
df.date.value_counts()
# Out:
# 2021-09-23    247
# 2021-08-22    247
# 2021-09-20    247
# 2021-09-21    247
# 2021-09-22    247
#              ...
# 2020-01-08      3
# 2020-01-07      3
# 2020-01-03      2
# 2020-01-01      2
# 2020-01-02      2
# Name: date, Length: 1154, dtype: int64

# %%
df.date.unique()
# Out:
# array(['2020-02-24', '2020-02-25', '2020-02-26', ..., '2020-02-10',
#        '2020-02-11', '2020-02-12'], dtype=object)

# %%
#df.drop(df[(df['continent'] == 'Europe') | (df['continent'] == 'Africa') | (df['continent'] == 'Asia') | (df['continent'] == 'North America') | (df['continent'] == 'Oceania') ].index, inplace=True)

# %%
index_df = df[(df['continent'] == 'Europe') | (df['continent'] == 'Africa') | (df['continent'] == 'Asia') | (df['continent'] == 'North America') | (df['continent'] == 'Oceania') ].index

# %%
df['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df.drop(index_df, inplace= True)

# %%
df['continent'].unique()
# Out:
# array([nan, 'South America'], dtype=object)

# %%
df = df.dropna(subset=['continent'])

# %%
df
# Out:
#        iso_code      continent   location        date  total_cases  new_cases  \
# 8726        ARG  South America  Argentina  2020-01-01          NaN        NaN
# 8727        ARG  South America  Argentina  2020-01-02          NaN        NaN
# 8728        ARG  South America  Argentina  2020-01-03          NaN        NaN
# 8729        ARG  South America  Argentina  2020-01-04          NaN        NaN
# 8730        ARG  South America  Argentina  2020-01-05          NaN        NaN
# ...         ...            ...        ...         ...          ...        ...
# 253161      VEN  South America  Venezuela  2023-02-23     551954.0       14.0
# 253162      VEN  South America  Venezuela  2023-02-24     551954.0        0.0
# 253163      VEN  South America  Venezuela  2023-02-25     551957.0        3.0
# 253164      VEN  South America  Venezuela  2023-02-26     551974.0       17.0
# 253165      VEN  South America  Venezuela  2023-02-27     551974.0        0.0
#
# ...

# %%
df['continent'].unique()
# Out:
# array(['South America'], dtype=object)

# %%
df_copy = df.copy(deep = True)
df_copy2 = df.copy(deep = True)

# %%
df_copy.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
#continent, location, date, total_cases, new_cases, total_deaths, population
#new_vaccinations
#RollingPeopleVaccinated

df_copy = df_copy[['iso_code', 'continent', 'location', 'date', 'population','total_cases', 'new_cases',
       'new_cases_smoothed', 'total_deaths', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients',
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million']]

# %%
df_copy.head()
# Out:
#      iso_code      continent   location        date  population  total_cases  \
# 8726      ARG  South America  Argentina  2020-01-01  45510324.0          NaN
# 8727      ARG  South America  Argentina  2020-01-02  45510324.0          NaN
# 8728      ARG  South America  Argentina  2020-01-03  45510324.0          NaN
# 8729      ARG  South America  Argentina  2020-01-04  45510324.0          NaN
# 8730      ARG  South America  Argentina  2020-01-05  45510324.0          NaN
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 8726        NaN                 NaN           NaN         NaN  ...
# 8727        NaN                 NaN           NaN         NaN  ...
# 8728        NaN                 NaN           NaN         NaN  ...
# 8729        NaN                 NaN           NaN         NaN  ...
# 8730        NaN                 NaN           NaN         NaN  ...
#
#       new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# ...

# %%
df_copy.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million'],
#       dtype='object')

# %%
pd.value_counts(df_copy['continent'])
# Out:
# South America    14184
# Name: continent, dtype: int64

# %%
df_copy['continent'].unique()
# Out:
# array(['South America'], dtype=object)

# %%
df_copy.head()
# Out:
#      iso_code      continent   location        date  population  total_cases  \
# 8726      ARG  South America  Argentina  2020-01-01  45510324.0          NaN
# 8727      ARG  South America  Argentina  2020-01-02  45510324.0          NaN
# 8728      ARG  South America  Argentina  2020-01-03  45510324.0          NaN
# 8729      ARG  South America  Argentina  2020-01-04  45510324.0          NaN
# 8730      ARG  South America  Argentina  2020-01-05  45510324.0          NaN
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 8726        NaN                 NaN           NaN         NaN  ...
# 8727        NaN                 NaN           NaN         NaN  ...
# 8728        NaN                 NaN           NaN         NaN  ...
# 8729        NaN                 NaN           NaN         NaN  ...
# 8730        NaN                 NaN           NaN         NaN  ...
#
#       new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# ...

# %%
df_copy.isnull().sum()
# Out:
# iso_code                                  0
# continent                                 0
# location                                  0
# date                                      0
# population                                0
# total_cases                              63
# new_cases                                94
# new_cases_smoothed                      172
# total_deaths                           1283
# new_deaths                             1302
# new_deaths_smoothed                    1363
# total_cases_per_million                  63
# new_cases_per_million                    94
# new_cases_smoothed_per_million          172
# total_deaths_per_million               1283
# new_deaths_per_million                 1302
# new_deaths_smoothed_per_million        1363
# reproduction_rate                      2110
# icu_patients                          11955
# icu_patients_per_million              11955
# hosp_patients                         13660
# ...

# %% [markdown]
# ~~~
# PARTE 2
# ~~~

# %%
df_copy2.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df_copy2= df_copy2[['iso_code', 'continent', 'location', 'date', 'total_tests', 'new_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
       'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
       'new_vaccinations', 'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
       'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
       'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
       'diabetes_prevalence', 'female_smokers', 'male_smokers',
       'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index',
       'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
       'excess_mortality', 'excess_mortality_cumulative_per_million']]

# %%
df_copy2.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
# ...

# %%
df_copy2.head()
# Out:
#      iso_code      continent   location        date  total_tests  new_tests  \
# 8726      ARG  South America  Argentina  2020-01-01          4.0        4.0
# 8727      ARG  South America  Argentina  2020-01-02         99.0       95.0
# 8728      ARG  South America  Argentina  2020-01-03        104.0        5.0
# 8729      ARG  South America  Argentina  2020-01-04        180.0       76.0
# 8730      ARG  South America  Argentina  2020-01-05        194.0       14.0
#
#       total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 8726                     0.000                   0.000                 NaN
# 8727                     0.002                   0.002                 NaN
# 8728                     0.002                   0.000                 NaN
# 8729                     0.004                   0.002                 NaN
# 8730                     0.004                   0.000                 NaN
#
# ...

# %%
# 14623 Valores vacios
df_copy2.isnull().sum()
# Out:
# iso_code                                          0
# continent                                         0
# location                                          0
# date                                              0
# total_tests                                    7346
# new_tests                                      8199
# total_tests_per_thousand                       7346
# new_tests_per_thousand                         8199
# new_tests_smoothed                             6159
# new_tests_smoothed_per_thousand                6159
# positive_rate                                  7531
# tests_per_case                                 7544
# tests_units                                    6082
# total_vaccinations                             8346
# people_vaccinated                              8427
# people_fully_vaccinated                        8532
# total_boosters                                10320
# new_vaccinations                               8829
# ...

# %%
#14184 valores no vacios
df_copy2.count()
# Out:
# iso_code                                      14184
# continent                                     14184
# location                                      14184
# date                                          14184
# total_tests                                    6838
# new_tests                                      5985
# total_tests_per_thousand                       6838
# new_tests_per_thousand                         5985
# new_tests_smoothed                             8025
# new_tests_smoothed_per_thousand                8025
# positive_rate                                  6653
# tests_per_case                                 6640
# tests_units                                    8102
# total_vaccinations                             5838
# people_vaccinated                              5757
# people_fully_vaccinated                        5652
# total_boosters                                 3864
# new_vaccinations                               5355
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14184 entries, 8726 to 253165
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    14184 non-null  object
#  1   continent                                   14184 non-null  object
#  2   location                                    14184 non-null  object
#  3   date                                        14184 non-null  object
#  4   total_cases                                 14121 non-null  float64
#  5   new_cases                                   14090 non-null  float64
#  6   new_cases_smoothed                          14012 non-null  float64
#  7   total_deaths                                12901 non-null  float64
#  8   new_deaths                                  12882 non-null  float64
# ...

# %%
pd.value_counts(df_copy2['continent'])
# Out:
# South America    14184
# Name: continent, dtype: int64

# %%
df_copy2['continent'].unique()
# Out:
# array(['South America'], dtype=object)

# %%
df_copy2.notnull().sum()
# Out:
# iso_code                                      14184
# continent                                     14184
# location                                      14184
# date                                          14184
# total_tests                                    6838
# new_tests                                      5985
# total_tests_per_thousand                       6838
# new_tests_per_thousand                         5985
# new_tests_smoothed                             8025
# new_tests_smoothed_per_thousand                8025
# positive_rate                                  6653
# tests_per_case                                 6640
# tests_units                                    8102
# total_vaccinations                             5838
# people_vaccinated                              5757
# people_fully_vaccinated                        5652
# total_boosters                                 3864
# new_vaccinations                               5355
# ...

# %%
df_copy2.shape
# Out:
# (14184, 45)

# %%
df_copy.shape
# Out:
# (14184, 26)

# %%
df_copy2.head()
# Out:
#      iso_code      continent   location        date  total_tests  new_tests  \
# 8726      ARG  South America  Argentina  2020-01-01          4.0        4.0
# 8727      ARG  South America  Argentina  2020-01-02         99.0       95.0
# 8728      ARG  South America  Argentina  2020-01-03        104.0        5.0
# 8729      ARG  South America  Argentina  2020-01-04        180.0       76.0
# 8730      ARG  South America  Argentina  2020-01-05        194.0       14.0
#
#       total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 8726                     0.000                   0.000                 NaN
# 8727                     0.002                   0.002                 NaN
# 8728                     0.002                   0.000                 NaN
# 8729                     0.004                   0.002                 NaN
# 8730                     0.004                   0.000                 NaN
#
# ...

# %%
df_copy.head()
# Out:
#      iso_code      continent   location        date  population  total_cases  \
# 8726      ARG  South America  Argentina  2020-01-01  45510324.0          NaN
# 8727      ARG  South America  Argentina  2020-01-02  45510324.0          NaN
# 8728      ARG  South America  Argentina  2020-01-03  45510324.0          NaN
# 8729      ARG  South America  Argentina  2020-01-04  45510324.0          NaN
# 8730      ARG  South America  Argentina  2020-01-05  45510324.0          NaN
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 8726        NaN                 NaN           NaN         NaN  ...
# 8727        NaN                 NaN           NaN         NaN  ...
# 8728        NaN                 NaN           NaN         NaN  ...
# 8729        NaN                 NaN           NaN         NaN  ...
# 8730        NaN                 NaN           NaN         NaN  ...
#
#       new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# ...

# %%
df_copy.to_excel('MuertesCovid.xlsx', index = False, sheet_name= 'MuertesCovid')
df_copy2.to_excel('VacunasCovid.xlsx', index = False, sheet_name= 'VacunasCovid')

# %% [markdown]
# ~~~
# EDA
# ~~~

# %%
df_copy.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'total_cases'}>,
#         <Axes: title={'center': 'new_cases'}>,
#         <Axes: title={'center': 'new_cases_smoothed'}>,
#         <Axes: title={'center': 'total_deaths'}>],
#        [<Axes: title={'center': 'new_deaths'}>,
#         <Axes: title={'center': 'new_deaths_smoothed'}>,
#         <Axes: title={'center': 'total_cases_per_million'}>,
#         <Axes: title={'center': 'new_cases_per_million'}>,
#         <Axes: title={'center': 'new_cases_smoothed_per_million'}>],
#        [<Axes: title={'center': 'total_deaths_per_million'}>,
#         <Axes: title={'center': 'new_deaths_per_million'}>,
#         <Axes: title={'center': 'new_deaths_smoothed_per_million'}>,
#         <Axes: title={'center': 'reproduction_rate'}>,
#         <Axes: title={'center': 'icu_patients'}>],
#        [<Axes: title={'center': 'icu_patients_per_million'}>,
#         <Axes: title={'center': 'hosp_patients'}>,
# ...

# %%
df_copy2.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'total_tests'}>,
#         <Axes: title={'center': 'new_tests'}>,
#         <Axes: title={'center': 'total_tests_per_thousand'}>,
#         <Axes: title={'center': 'new_tests_per_thousand'}>,
#         <Axes: title={'center': 'new_tests_smoothed'}>,
#         <Axes: title={'center': 'new_tests_smoothed_per_thousand'}>],
#        [<Axes: title={'center': 'positive_rate'}>,
#         <Axes: title={'center': 'tests_per_case'}>,
#         <Axes: title={'center': 'total_vaccinations'}>,
#         <Axes: title={'center': 'people_vaccinated'}>,
#         <Axes: title={'center': 'people_fully_vaccinated'}>,
#         <Axes: title={'center': 'total_boosters'}>],
#        [<Axes: title={'center': 'new_vaccinations'}>,
#         <Axes: title={'center': 'new_vaccinations_smoothed'}>,
#         <Axes: title={'center': 'total_vaccinations_per_hundred'}>,
#         <Axes: title={'center': 'people_vaccinated_per_hundred'}>,
# ...

# %%
sns.boxplot(x="total_cases", y="location", data = df_copy, notch = True)
# Out:
# <Axes: xlabel='total_cases', ylabel='location'>

# %%
df_copy2.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
# ...

# %%
sns.boxplot(x="people_vaccinated", y="location", data = df_copy2, notch = True)
# Out:
# <Axes: xlabel='people_vaccinated', ylabel='location'>

# %%
sns.boxplot(x="total_vaccinations", y="location", data = df_copy2, notch = True)
# Out:
# <Axes: xlabel='total_vaccinations', ylabel='location'>

# %%
df_copy2['total_vaccinations'].unique()
# Out:
# array([          nan, 2.0492000e+04, 4.0592000e+04, ..., 3.5352675e+07,
#        3.6962256e+07, 3.7860994e+07])

# %%
df_copy2['people_vaccinated'].unique()
# Out:
# array([          nan, 2.0489000e+04, 4.0584000e+04, ..., 2.0836636e+07,
#        2.1737740e+07, 2.2157232e+07])
